# %% [markdown]
# <a href="https://colab.research.google.com/github/gcerda15/Poli-179-Project-/blob/main/POLI_179_Final_Project_College_Essays.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-232a70ba-1610-4a1d-be1e-fae6907bc3db" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-232a70ba-1610-4a1d-be1e-fae6907bc3db">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df = pd.read_csv('merged_final.csv')
df
# Out:
#           ID  FAMILY_INCOME  RSAT_TOTAL_SCORE  RSAT_EBRW  RSAT_MATH_SCORE  \
# 0          1         180000              1350        650              700
# 1          2         175000              1200        570              630
# 2          3          32000               990        470              520
# 3          4          56000              1150        570              580
# 4          5         600000              1370        670              700
# ...      ...            ...               ...        ...              ...
# 59718  59996         160000              1250        570              680
# 59719  59997          18650              1160        610              550
# 59720  59998         100000              1260        630              630
# 59721  59999         200000              1350        690              660
# 59722  60000          18887              1000        510              490
#
#        Winning_Competitions      Math  AP_Classes  Work_And_Goals  \
# ...

# %%
print (df.columns)
# Out:
# Index(['ID', 'FAMILY_INCOME', 'RSAT_TOTAL_SCORE', 'RSAT_EBRW',
#        'RSAT_MATH_SCORE', 'Winning_Competitions', 'Math', 'AP_Classes',
#        'Work_And_Goals', 'Camping_Swimming',
#        ...
#        'Period', 'Comma', 'Colon', 'SemiC', 'QMark', 'Exclam', 'Quote',
#        'Apostro', 'Parenth', 'OtherP'],
#       dtype='object', length=167)

# %%
drop_columns = ['RSAT_TOTAL_SCORE', 'RSAT_EBRW', 'RSAT_MATH_SCORE', 'Analytic', 'Clout', 'Authentic', 'Tone', 'WPS', 'Sixltr', 'Dic', 'function', 'pronoun', 'ppron', 'i', 'we', 'you', 'shehe', 'they', 'ipron', 'article', 'prep', 'auxverb', 'adverb', 'conj', 'negate', 'verb', 'adj', 'AllPunc', 'Period', 'Comma', 'Colon', 'SemiC', 'QMark', 'Exclam', 'Quote', 'Apostro', 'Parenth', 'OtherP']

# %%
df = df.drop(columns=drop_columns)
print(df.columns)
# Out:
# Index(['ID', 'FAMILY_INCOME', 'Winning_Competitions', 'Math', 'AP_Classes',
#        'Work_And_Goals', 'Camping_Swimming', 'Social_Anxiety',
#        'Gendered_Activities', 'Fashion_Style',
#        ...
#        'home', 'money', 'relig', 'death', 'informal', 'swear', 'netspeak',
#        'assent', 'nonflu', 'filler'],
#       dtype='object', length=129)

# %%
df
# Out:
#           ID  FAMILY_INCOME  Winning_Competitions      Math  AP_Classes  \
# 0          1         180000              0.002242  0.000934    0.009605
# 1          2         175000              0.004480  0.000736    0.008061
# 2          3          32000              0.000353  0.007873    0.021253
# 3          4          56000              0.001888  0.038390    0.003707
# 4          5         600000              0.032499  0.002569    0.012160
# ...      ...            ...                   ...       ...         ...
# 59718  59996         160000              0.003455  0.030667    0.011292
# 59719  59997          18650              0.000920  0.003820    0.030767
# 59720  59998         100000              0.001254  0.002031    0.006140
# 59721  59999         200000              0.025663  0.000602    0.002429
# 59722  60000          18887              0.000873  0.034443    0.012786
#
#        Work_And_Goals  Camping_Swimming  Social_Anxiety  Gendered_Activities  \
# ...

# %%
pip install bertopic

# %%
import numpy as np
import bertopic
from bertopic import BERTopic
from sklearn.preprocessing import StandardScaler

# %%
high_income_threshold = 150000
low_income_threshold = 30000

high_income = df[df['FAMILY_INCOME'] > high_income_threshold]
low_income = df[df['FAMILY_INCOME'] > low_income_threshold]

# %%
df.rename(columns = {
    '':'word_'
    'Winning_Competitions':'topic_Winning_Competitions'
    'Math':'topic_Math'
    'AP_Classes':'topic_AP_Classes'
    'Work_And_Goals':'topic_Work_And_Goals'
    'Camping_Swimming':'topic_Camping_Swimming'
    'Social_Anxiety':'topic_Social_Anxiety'
    'Gendered_Activities':'topic_Gendered_Activities'
    'Fashion_Style':'topic_Fashion_Style'
    'Family_Members':'topic_Family_Members'
    'Medical_Experiences':'topic_Medical_Experiences'
    'Helping_Others':'topic_Helping_Others'
    'Despite_Words':'topic_Despite_Words'
    'Latinx_Family_Issues':'topic_Latinx_Family_Issues'
    'Education_Opportunity':'topic_Education_Opportunity'
}, inplace=True)

# %%
def construct_synthetic_documents(df):
  documents = []
  for _, row in df.iterrows():
    document = []
    for col in df.columns:
